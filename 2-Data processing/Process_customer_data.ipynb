# %% [markdown]
# # We pretend to process data here. For some big projects, when we want to separate data from Machine Learning models, we do separate data processing from model training. If your model is small, we often do data processing as part of model development before we start training.

# %%
import pandas as pd
file = "...."
df = read_csv(file)
